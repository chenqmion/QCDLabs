# %%
import sys
sys.path.insert(0, '../instrument/')
from SRS.instr_SIM900 import SIM900

# %%
_address = "10.0.100.113"
_instr = SIM900(_address, slot=1)

# %%
_instr.voltage(0.05)

# %%
_instr.output(1)

# %%
_instr.slow_set(0.501, dv=0.01)

# %%
_instr.slow_set(0, dv=0.05)

# %%
_instr.output(0)

# %%
_instr.status
# Out:
# {'name': 'SIM900 slot 1', 'voltage': 0.05, 'output': 1}
