# %%
import os

import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, '../../instrument/')
from Agilent.instr_N9928A import N9928A

# %%
_address = "10.0.100.110"
_instr = N9928A(_address)
# Out:
# Connected to N9928A [10.0.100.110:5025].

# %%
_instr.reference('EXT')
_instr.start_frequency(0.1e9)
_instr.stop_frequency(20.1e9)
_instr.if_frequency(1e3)
_instr.average(10, mode='sweep')
_instr.points(1001)
_instr.power(-10)

# %% [markdown]
# # K1

# %%
res_k1 = _instr.get_trace()

# %%
res_k1.to_zarr('k1.zarr')

# %%
# with xr.open_zarr("k1.zarr") as f:
#     raw_data = f['S21']

# %%
plt.figure()
plt.plot(res_k1.frequency_hz, 20*np.log10(np.abs(res_k1.data)))
plt.show()

# %% [markdown]
# # K2

# %%
res_k2 = _instr.get_trace()
res_k2.to_zarr('k2.zarr')

# %%
plt.figure()
plt.plot(res_k1.frequency_hz, 20*np.log10(np.abs(res_k1.data)))
plt.plot(res_k2.frequency_hz, 20*np.log10(np.abs(res_k2.data)))
plt.show()

# %% [markdown]
# # K3

# %%
res_k3 = _instr.get_trace()
res_k3.to_zarr('k3.zarr')

# %%
with xr.open_zarr("k3.zarr") as f:
    res_k3 = f['S21']

# %%
plt.figure()
plt.plot(res_k1.frequency_hz, 20*np.log10(np.abs(res_k1.data)))
plt.plot(res_k2.frequency_hz, 20*np.log10(np.abs(res_k2.data)))
plt.plot(res_k3.frequency_hz, 20*np.log10(np.abs(res_k3.data)))
plt.show()

# %% [markdown]
# # K4

# %%
res_k4 = _instr.get_trace()
res_k4.to_zarr('k4.zarr')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[56], line 2
#       1 res_k4 = _instr.get_trace()
# ----> 2 res_k4.to_zarr('k4.zarr')
#
# File ~\anaconda3\envs\QCDLabs\Lib\site-packages\xarray\core\dataarray.py:4506, in DataArray.to_zarr(self, store, chunk_store, mode, synchronizer, group, encoding, compute, consolidated, append_dim, region, safe_chunks, align_chunks, storage_options, zarr_version, zarr_format, write_empty_chunks, chunkmanager_store_kwargs)
#    4502 else:
#    4503     # No problems with the name - so we're fine!
#    4504     dataset = self.to_dataset()
# -> 4506 return to_zarr(  # type: ignore[call-overload,misc]
#    4507     dataset,
#    4508     store=store,
#    4509     chunk_store=chunk_store,
#    4510     mode=mode,
#    4511     synchronizer=synchronizer,
#    4512     group=group,
#    4513     encoding=encoding,
# ...

# %%
plt.figure()
plt.plot(res_k1.frequency_hz, 20*np.log10(np.abs(res_k1.data)))
plt.plot(res_k2.frequency_hz, 20*np.log10(np.abs(res_k2.data)))
plt.plot(res_k3.frequency_hz, 20*np.log10(np.abs(res_k3.data)))
plt.plot(res_k4.frequency_hz, 20*np.log10(np.abs(res_k4.data)))
plt.show()

# %% [markdown]
# # S1

# %%
res_s1 = _instr.get_trace()
res_s1.to_zarr('s1.zarr')
# Out:
# C:\Users\qcduser\anaconda3\envs\QCDLabs\Lib\site-packages\zarr\api\asynchronous.py:247: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(

# %%
plt.figure()
plt.plot(res_s1.frequency_hz, 20*np.log10(np.abs(res_s1.data)))
plt.show()

# %% [markdown]
# # S2

# %%
res_s2 = _instr.get_trace()
res_s2.to_zarr('s2.zarr')
# Out:
# C:\Users\qcduser\anaconda3\envs\QCDLabs\Lib\site-packages\zarr\api\asynchronous.py:247: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(

# %%
plt.figure()
plt.plot(res_s1.frequency_hz, 20*np.log10(np.abs(res_s1.data)))
plt.plot(res_s2.frequency_hz, 20*np.log10(np.abs(res_s2.data)))
plt.show()

# %% [markdown]
# # S3

# %%
res_s3 = _instr.get_trace()
res_s3.to_zarr('s3.zarr')
# Out:
# C:\Users\qcduser\anaconda3\envs\QCDLabs\Lib\site-packages\zarr\api\asynchronous.py:247: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(

# %%
plt.figure()
plt.plot(res_s1.frequency_hz, 20*np.log10(np.abs(res_s1.data)))
plt.plot(res_s2.frequency_hz, 20*np.log10(np.abs(res_s2.data)))
plt.plot(res_s3.frequency_hz, 20*np.log10(np.abs(res_s3.data)))
plt.show()

# %% [markdown]
# # S4

# %%
res_s4 = _instr.get_trace()
res_s4.to_zarr('s4.zarr')

# %%
plt.figure()
plt.plot(res_k1.frequency_hz, 20*np.log10(np.abs(res_k1.data)))
plt.plot(res_k2.frequency_hz, 20*np.log10(np.abs(res_k2.data)))
plt.plot(res_k3.frequency_hz, 20*np.log10(np.abs(res_k3.data)))
plt.plot(res_k4.frequency_hz, 20*np.log10(np.abs(res_k4.data)))
plt.plot(res_s1.frequency_hz, 20*np.log10(np.abs(res_s1.data)))
plt.plot(res_s2.frequency_hz, 20*np.log10(np.abs(res_s2.data)))
plt.plot(res_s3.frequency_hz, 20*np.log10(np.abs(res_s3.data)))
plt.plot(res_s4.frequency_hz, 20*np.log10(np.abs(res_s4.data)))
plt.show()

# %%
plt.figure()
plt.plot(res_s1.frequency_hz, 20*np.log10(np.abs(res_s1.data)))
plt.plot(res_s2.frequency_hz, 20*np.log10(np.abs(res_s2.data)))
plt.plot(res_s3.frequency_hz, 20*np.log10(np.abs(res_s3.data)))
plt.plot(res_s4.frequency_hz, 20*np.log10(np.abs(res_s4.data)))
plt.show()

# %% [markdown]
# # S5

# %%
res_s5 = _instr.get_trace()
res_s5.to_zarr('s5.zarr')

# %%
plt.figure()
plt.plot(res_s5.frequency_hz, 20*np.log10(np.abs(res_s5.data)))
plt.show()

# %% [markdown]
# # S6

# %%
res_s6 = _instr.get_trace()
res_s6.to_zarr('s6.zarr')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[96], line 2
#       1 res_s6 = _instr.get_trace()
# ----> 2 res_s6.to_zarr('s6.zarr')
#
# File ~\anaconda3\envs\QCDLabs\Lib\site-packages\xarray\core\dataarray.py:4506, in DataArray.to_zarr(self, store, chunk_store, mode, synchronizer, group, encoding, compute, consolidated, append_dim, region, safe_chunks, align_chunks, storage_options, zarr_version, zarr_format, write_empty_chunks, chunkmanager_store_kwargs)
#    4502 else:
#    4503     # No problems with the name - so we're fine!
#    4504     dataset = self.to_dataset()
# -> 4506 return to_zarr(  # type: ignore[call-overload,misc]
#    4507     dataset,
#    4508     store=store,
#    4509     chunk_store=chunk_store,
#    4510     mode=mode,
#    4511     synchronizer=synchronizer,
#    4512     group=group,
#    4513     encoding=encoding,
# ...

# %%
plt.figure()
plt.plot(res_s6.frequency_hz, 20*np.log10(np.abs(res_s6.data)))
plt.show()

# %% [markdown]
# # S7

# %%
res_s7 = _instr.get_trace()
res_s7.to_zarr('s7.zarr')
# Out:
# C:\Users\qcduser\anaconda3\envs\QCDLabs\Lib\site-packages\zarr\api\asynchronous.py:247: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(

# %%
plt.figure()
plt.plot(res_s5.frequency_hz, 20*np.log10(np.abs(res_s5.data)))
plt.plot(res_s6.frequency_hz, 20*np.log10(np.abs(res_s6.data)))
plt.plot(res_s7.frequency_hz, 20*np.log10(np.abs(res_s7.data)))
plt.show()

# %%
sys.path.insert(0, '../pattern/')

# %load_ext autoreload
# %autoreload 1

# %aimport helper_sweep
from helper_sweep import do_sweep

# %%
file_path = os.path.join(os.getcwd(), 'test_Agilent_N9928A.zarr')

# %%
config_device = [_instr]
config_sweep = [
    [_instr.power, {'power_dbm': np.arange(-30, -20+1e-6, 10)}]
    ]

# %%
do_sweep(config_device, config_sweep, _instr.get_trace, file_path)
# Out:
# 100%|██████████| 2/2 [00:15<00:00,  7.57s/it]

# %%
with xr.open_zarr("test_Agilent_N9928A.zarr", consolidated=False) as f:
    raw_data = f['S21']

# %%
plt.figure()
plt.pcolormesh(raw_data.N9928A_frequency_hz/1e9, raw_data.N9928A_power_dbm, 20*np.log10(np.abs(raw_data)).squeeze())
plt.colorbar()
plt.show()
# plt.xlim(6.75, 6.785)
plt.show()

# %%
raw_data
# Out:
# <xarray.DataArray 'S21' (N9928A_power_dbm: 2, N9928A_frequency_hz: 1001,
#                          N9928A_if_frequency_hz: 1, N9928A_average: 1,
#                          N9928A_mode: 1, N9928A_reference: 1)> Size: 32kB
# dask.array<open_dataset-S21, shape=(2, 1001, 1, 1, 1, 1), dtype=complex128, chunksize=(1, 1001, 1, 1, 1, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * N9928A_power_dbm        (N9928A_power_dbm) float64 16B -30.0 -20.0
#   * N9928A_frequency_hz     (N9928A_frequency_hz) float64 8kB 6.45e+09 ... 6....
#   * N9928A_if_frequency_hz  (N9928A_if_frequency_hz) float64 8B 1e+03
#   * N9928A_average          (N9928A_average) int32 4B 2
#   * N9928A_mode             (N9928A_mode) <U5 20B 'sweep'
#   * N9928A_reference        (N9928A_reference) float64 8B nan
